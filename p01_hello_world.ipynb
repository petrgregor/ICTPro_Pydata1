# %% [markdown]
# # Nadpis 1. úrovně
# ## Nadpis 2. úrovně
#
# - první odrážka
# - druhá odrážka
#   1. číslovaná položka
#   2. druhá
#   1. třetí
# - třetí odrážka
#
# *Text v kurzívě*
# **Tučný text**

# %% [markdown]
# # Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Proměnné a výpis

# %%
#print(f"num = {num}")

# %% [markdown]
# Provádění kódu mimo pořadí

# %%
a = 20

# %%
print(a)
# Out:
# 20

# %%
a = 100

# %% [markdown]
# # Magické příkazy

# %%
# %who
# Out:
# a

# %%
# Measure execution time of a cell
# %time
data_list = [x for x in range (1000000)]
# Out:
# CPU times: total: 0 ns
# Wall time: 6.44 μs
