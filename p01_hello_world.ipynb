# %% [markdown]
# # Nadpis 1. úrovně
# ## Nadpis 2. úrovně
#
# - první odrážka
# - druhá odrážka
#   1. číslovaná položka
#   2. druhá
#   1. třetí
# - třetí odrážka
#
# *Text v kurzívě*
# **Tučný text**

# %% [markdown]
# # Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Proměnné a výpis

# %%
num = 50
print(f"num = {num}")
# Out:
# num = 50
