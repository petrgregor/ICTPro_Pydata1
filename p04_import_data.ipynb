# %% [markdown]
# # Import dat do Pandas
# ## CSV

# %%
import pandas as pd
weather = pd.read_csv('./data/pydata_data.csv', sep=";")
weather.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 67834 entries, 0 to 67833
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  67834 non-null  str
#  1   NAME     67834 non-null  str
#  2   DATE     67834 non-null  str
#  3   PRCP     56483 non-null  float64
#  4   SNWD     17540 non-null  float64
#  5   TAVG     59664 non-null  float64
#  6   TMAX     51147 non-null  float64
#  7   TMIN     50830 non-null  float64
# dtypes: float64(5), str(3)
# memory usage: 4.1 MB

# %%
print(weather.shape)
# Out:
# (67834, 8)

# %%
print(weather.describe())
# Out:
#                PRCP          SNWD          TAVG          TMAX          TMIN
# count  56483.000000  17540.000000  59664.000000  51147.000000  50830.000000
# mean       2.390054     29.513512     10.169048     15.272442      5.724139
# std        6.191885     59.993963      8.342663      9.508819      7.481063
# min        0.000000      0.000000    -21.600000    -17.400000    -23.600000
# 25%        0.000000      0.000000      3.600000      7.700000      0.200000
# 50%        0.000000      0.000000     10.500000     16.100000      6.000000
# 75%        1.800000     30.000000     16.900000     22.900000     11.800000
# max      140.000000   1400.000000     30.300000     39.600000     25.300000

# %%
print(weather.head())
# Out:
#        STATION    NAME        DATE  PRCP  SNWD  TAVG  TMAX  TMIN
# 0  GME00132274  PIDING  2006-12-01   0.0   0.0   NaN   4.2   1.0
# 1  GME00132274  PIDING  2006-12-02   0.0   0.0   NaN   1.8  -1.7
# 2  GME00132274  PIDING  2006-12-03   0.0   0.0   NaN   5.1  -4.6
# 3  GME00132274  PIDING  2006-12-04  19.0   0.0   NaN   8.3  -0.9
# 4  GME00132274  PIDING  2006-12-05   0.0   0.0   NaN  12.0   0.9

# %% [markdown]
# ## HTML

# %%
#import lxml
url = 'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population'

#tables = pd.read_html()

#print(tables)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 #import lxml
#       2 url = 'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population'
# ----> 4 table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')
#       5 #tables = pd.read_html()
#       6
#       7 #print(tables)
#
# File ~\PycharmProjects\ICTPro_Pydata1\.venv\Lib\site-packages\pandas\io\html.py:1226, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1222 check_dtype_backend(dtype_backend)
#    1224 io = stringify_path(io)
# -> 1226 return _parse(
#    1227     flavor=flavor,
#    1228     io=io,
#    1229     match=match,
#    1230     header=header,
#    1231     index_col=index_col,
# ...

# %% [markdown]
# # Export dat z Pandas
# ## Do Excelu

# %%
weather.to_excel('./data/weather.xlsx', index=False)
